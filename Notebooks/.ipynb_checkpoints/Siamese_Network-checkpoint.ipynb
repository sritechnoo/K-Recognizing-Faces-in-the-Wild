# %%
import os
from PIL import Image

# %%
import numpy as np

# %%
from keras.models import Sequential,Model

from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Lambda, Flatten, Dense
from keras.layers.merge import Concatenate

from keras.initializers import glorot_uniform
from keras.regularizers import l2

from keras.optimizers import Adam
from keras import losses
from keras import metrics

from keras import backend as K

from keras.utils import plot_model

from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
def initialize_weights(shape, name=None):
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

# %%
def initialize_bias(shape, name=None):
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def get_siamese_model(input_shape):
    model = Sequential()
    
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
                     kernel_initializer=initialize_weights, 
                     kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights, bias_initializer=initialize_bias,
                     kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(128, (4,4), activation='relu', 
                     kernel_initializer=initialize_weights, bias_initializer=initialize_bias, 
                     kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(256, (4,4), activation='relu', 
                     kernel_initializer=initialize_weights, bias_initializer=initialize_bias, 
                     kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    
    model.add(Dense(4096, activation='sigmoid',
                   kernel_initializer=initialize_weights, bias_initializer=initialize_bias,
                   kernel_regularizer=l2(1e-3)))
    
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)
        
    euclidian_distance = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))([encoded_l, encoded_r])
    prediction = Dense(1,activation='sigmoid', bias_initializer=initialize_bias)(euclidian_distance)
    
    siamese_model = Model(inputs=[left_input,right_input], outputs=prediction)
    
    siamese_model.compile(loss="binary_crossentropy",optimizer=Adam(lr = 0.00006))
    
    return siamese_model

# %%
model = get_siamese_model((224, 224, 3))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 4096)         420642112   input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 4096)         0           sequential_3[1][0]
#                                                                  sequential_3[2][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            4097        lambda_3[0][0]
# ==================================================================================================
# Total params: 420,646,209
# Trainable params: 420,646,209
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
import pickle
pickle_in = open("../Data/image_data.pkl","rb")
df_from_pickle = pickle.load(pickle_in)
pickle_in.close()

# %%
df_from_pickle.shape
# Out:
# (433539, 4)

# %%
msk_train_test = np.random.rand(len(df_from_pickle)) < 0.7
training_data = df_from_pickle[msk_train_test]
testing_data = df_from_pickle[~msk_train_test]

# %%
msk_train_val = np.random.rand(len(training_data)) < 0.8
train_df = training_data[msk_train_val]
validation_df = training_data[~msk_train_val]
test_df = testing_data

# %%
train_df
#validation_df
#test_df
# Out:
#        combination_pair_from_dir  \
# 0          F0002/MID1-F0002/MID2
# 2          F0002/MID1-F0002/MID2
# 3          F0002/MID1-F0002/MID2
# 5          F0002/MID1-F0002/MID2
# 6          F0002/MID1-F0002/MID2
# 8          F0002/MID1-F0002/MID2
# 11         F0002/MID1-F0002/MID2
# 13         F0002/MID1-F0002/MID2
# 14         F0002/MID1-F0002/MID2
# 18         F0002/MID1-F0002/MID2
# 19         F0002/MID1-F0002/MID2
# 20         F0002/MID1-F0002/MID2
# 21         F0002/MID1-F0002/MID2
# 22         F0002/MID1-F0002/MID2
# 23         F0002/MID1-F0002/MID2
# 24         F0002/MID1-F0002/MID2
# 25         F0002/MID1-F0002/MID2
# 27         F0002/MID1-F0002/MID2
# 28         F0002/MID1-F0002/MID2
# 32         F0002/MID1-F0002/MID2
# 36         F0002/MID1-F0002/MID2
# 41         F0002/MID1-F0002/MID2
# 45         F0002/MID1-F0002/MID2
# 46         F0002/MID1-F0002/MID2
# 56         F0002/MID1-F0002/MID2
# 60         F0002/MID1-F0002/MID2
# 61         F0002/MID1-F0002/MID2
# 62         F0002/MID1-F0002/MID2
# 63         F0002/MID1-F0002/MID2
# 64         F0002/MID1-F0002/MID2
# ...                          ...
# 433492     F1000/MID2-F1000/MID8
# 433493     F1000/MID2-F1000/MID8
# 433494     F1000/MID2-F1000/MID9
# 433495     F1000/MID2-F1000/MID9
# 433496     F1000/MID2-F1000/MID9
# 433498     F1000/MID3-F1000/MID4
# 433499     F1000/MID3-F1000/MID4
# 433500     F1000/MID3-F1000/MID4
# 433501     F1000/MID3-F1000/MID5
# 433502     F1000/MID3-F1000/MID6
# 433503     F1000/MID3-F1000/MID7
# 433507     F1000/MID4-F1000/MID5
# 433509     F1000/MID4-F1000/MID5
# 433510     F1000/MID4-F1000/MID6
# 433513     F1000/MID4-F1000/MID7
# 433514     F1000/MID4-F1000/MID7
# 433516     F1000/MID4-F1000/MID7
# 433518     F1000/MID4-F1000/MID7
# 433519     F1000/MID4-F1000/MID8
# 433520     F1000/MID4-F1000/MID8
# 433522     F1000/MID4-F1000/MID9
# 433524     F1000/MID4-F1000/MID9
# 433526     F1000/MID5-F1000/MID7
# 433527     F1000/MID5-F1000/MID7
# 433528     F1000/MID5-F1000/MID8
# 433530     F1000/MID6-F1000/MID7
# 433531     F1000/MID6-F1000/MID7
# 433532     F1000/MID6-F1000/MID8
# 433533     F1000/MID6-F1000/MID9
# 433538     F1000/MID8-F1000/MID9
#
#                                           left_image_path  \
# 0       ../Data/recognizing-faces-in-the-wild/train/F0...
# 2       ../Data/recognizing-faces-in-the-wild/train/F0...
# 3       ../Data/recognizing-faces-in-the-wild/train/F0...
# 5       ../Data/recognizing-faces-in-the-wild/train/F0...
# 6       ../Data/recognizing-faces-in-the-wild/train/F0...
# 8       ../Data/recognizing-faces-in-the-wild/train/F0...
# 11      ../Data/recognizing-faces-in-the-wild/train/F0...
# 13      ../Data/recognizing-faces-in-the-wild/train/F0...
# 14      ../Data/recognizing-faces-in-the-wild/train/F0...
# 18      ../Data/recognizing-faces-in-the-wild/train/F0...
# 19      ../Data/recognizing-faces-in-the-wild/train/F0...
# 20      ../Data/recognizing-faces-in-the-wild/train/F0...
# 21      ../Data/recognizing-faces-in-the-wild/train/F0...
# 22      ../Data/recognizing-faces-in-the-wild/train/F0...
# 23      ../Data/recognizing-faces-in-the-wild/train/F0...
# 24      ../Data/recognizing-faces-in-the-wild/train/F0...
# 25      ../Data/recognizing-faces-in-the-wild/train/F0...
# 27      ../Data/recognizing-faces-in-the-wild/train/F0...
# 28      ../Data/recognizing-faces-in-the-wild/train/F0...
# 32      ../Data/recognizing-faces-in-the-wild/train/F0...
# 36      ../Data/recognizing-faces-in-the-wild/train/F0...
# 41      ../Data/recognizing-faces-in-the-wild/train/F0...
# 45      ../Data/recognizing-faces-in-the-wild/train/F0...
# 46      ../Data/recognizing-faces-in-the-wild/train/F0...
# 56      ../Data/recognizing-faces-in-the-wild/train/F0...
# 60      ../Data/recognizing-faces-in-the-wild/train/F0...
# 61      ../Data/recognizing-faces-in-the-wild/train/F0...
# 62      ../Data/recognizing-faces-in-the-wild/train/F0...
# 63      ../Data/recognizing-faces-in-the-wild/train/F0...
# 64      ../Data/recognizing-faces-in-the-wild/train/F0...
# ...                                                   ...
# 433492  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433493  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433494  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433495  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433496  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433498  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433499  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433500  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433501  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433502  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433503  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433507  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433509  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433510  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433513  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433514  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433516  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433518  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433519  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433520  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433522  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433524  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433526  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433527  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433528  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433530  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433531  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433532  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433533  ../Data/recognizing-faces-in-the-wild/train/F1...
# 433538  ../Data/recognizing-faces-in-the-wild/train/F1...
#
#                                          right_image_path  is_related
# 0       ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 2       ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 3       ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 5       ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 6       ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 8       ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 11      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 13      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 14      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 18      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 19      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 20      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 21      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 22      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 23      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 24      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 25      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 27      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 28      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 32      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 36      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 41      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 45      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 46      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 56      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 60      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 61      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 62      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 63      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 64      ../Data/recognizing-faces-in-the-wild/train/F0...           0
# ...                                                   ...         ...
# 433492  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433493  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433494  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433495  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433496  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433498  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433499  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433500  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433501  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433502  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433503  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433507  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433509  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433510  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433513  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433514  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433516  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433518  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433519  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433520  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433522  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433524  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433526  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433527  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433528  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433530  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433531  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433532  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 433533  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 433538  ../Data/recognizing-faces-in-the-wild/train/F1...           0
#
# [242621 rows x 4 columns]

# %%
def batches_generator(batch_size, data_frame, shuffle=True):
    """Generates padded batches of tokens and tags."""
    
    n_samples = data_frame.shape[0]
    if shuffle:
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)

    n_batches = n_samples // batch_size
    
    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start
        
        left_image_list = []
        right_image_list = []
        is_related = []
        
        for idx in order[batch_start: batch_end]:
            left_image_array=np.asarray(Image.open(data_frame.iloc[idx]['left_image_path']))
            left_image_list.append(left_image_array)
            
            right_image_array=np.asarray(Image.open(data_frame.iloc[idx]['right_image_path']))
            right_image_list.append(right_image_array)
            
            is_related.append(data_frame.iloc[idx]['is_related'])
            
        #yield left_image_list, right_image_list, is_related
        yield ({'input_1': left_image_list, 'input_2': right_image_list}, {'output': is_related})

# %%
batch = ((batches_generator(10000, train_df, shuffle=False)))
batch

# %%
#next_item = next(batch)
#next_item

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto', restore_best_weights=True)
checkpoint = ModelCheckpoint(filepath='model_{epoch:02d}_{val_loss:.2f}.hdf5')

# %%
history = model.fit_generator(generator= batches_generator(1000, train_df, shuffle=True), 
                    steps_per_epoch=None, 
                    epochs=100, 
                    verbose=1, callbacks=[monitor,checkpoint], 
                    validation_data = batches_generator(1000, validation_df, shuffle=True), 
                    validation_steps=None, 
                    validation_freq=1, 
                    class_weight=None, 
                    max_queue_size=10, workers=1, 
                    use_multiprocessing=False, 
                    shuffle=True, initial_epoch=0)

# %%
model.save_weights("finalmodels/final.h5")
