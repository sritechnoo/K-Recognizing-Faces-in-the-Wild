# %%
import os
from PIL import Image

# %%
import numpy as np

# %%
from keras.models import Sequential,Model

from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Lambda, Flatten, Dense
from keras.layers.merge import Concatenate

from keras.initializers import glorot_uniform
from keras.regularizers import l2

from keras.optimizers import Adam
from keras import losses
from keras import metrics

from keras import backend as K

from keras.utils import plot_model

from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def initialize_weights(shape, name=None):
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

# %%
def initialize_bias(shape, name=None):
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def get_siamese_model(input_shape):
    model = Sequential()
    
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
                     kernel_initializer=initialize_weights, 
                     kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights, bias_initializer=initialize_bias,
                     kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(128, (4,4), activation='relu', 
                     kernel_initializer=initialize_weights, bias_initializer=initialize_bias, 
                     kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(256, (4,4), activation='relu', 
                     kernel_initializer=initialize_weights, bias_initializer=initialize_bias, 
                     kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    
    model.add(Dense(4096, activation='sigmoid',
                   kernel_initializer=initialize_weights, bias_initializer=initialize_bias,
                   kernel_regularizer=l2(1e-3)))
    
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)
        
    euclidian_distance = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))([encoded_l, encoded_r])
    prediction = Dense(1,activation='sigmoid', bias_initializer=initialize_bias)(euclidian_distance)
    
    siamese_model = Model(inputs=[left_input,right_input], outputs=prediction)
    
    siamese_model.compile(loss="binary_crossentropy",optimizer=Adam(lr = 0.00006))
    
    return siamese_model

# %%
model = get_siamese_model((224, 224, 3))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\srinivasan_b\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4096)         420642112   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4096)         0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            4097        lambda_1[0][0]
# ==================================================================================================
# Total params: 420,646,209
# Trainable params: 420,646,209
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
import pickle
pickle_in = open("../Data/image_data.pkl","rb")
df_from_pickle = pickle.load(pickle_in)
pickle_in.close()

# %%
df_from_pickle.shape
# Out:
# (12122, 4)

# %%
msk_train_test = np.random.rand(len(df_from_pickle)) < 0.7
training_data = df_from_pickle[msk_train_test]
testing_data = df_from_pickle[~msk_train_test]

# %%
msk_train_val = np.random.rand(len(training_data)) < 0.8
train_df = training_data[msk_train_val]
validation_df = training_data[~msk_train_val]
test_df = testing_data

# %%
train_df
#validation_df
#test_df
# Out:
#       combination_pair_from_dir  \
# 2         F0002/MID1-F0002/MID3
# 7         F0005/MID1-F0005/MID2
# 12        F0009/MID1-F0009/MID2
# 13        F0009/MID1-F0009/MID2
# 14        F0009/MID1-F0009/MID3
# 17        F0009/MID1-F0009/MID4
# 20        F0009/MID1-F0009/MID6
# 21        F0009/MID1-F0009/MID6
# 22        F0009/MID1-F0009/MID7
# 23        F0009/MID1-F0009/MID7
# 26        F0009/MID2-F0009/MID4
# 27        F0009/MID2-F0009/MID4
# 29        F0009/MID2-F0009/MID5
# 35        F0009/MID3-F0009/MID4
# 36        F0009/MID3-F0009/MID5
# 42        F0009/MID4-F0009/MID5
# 43        F0009/MID4-F0009/MID5
# 44        F0009/MID4-F0009/MID6
# 46        F0009/MID4-F0009/MID7
# 47        F0009/MID4-F0009/MID7
# 48        F0009/MID5-F0009/MID6
# 50        F0009/MID5-F0009/MID7
# 51        F0009/MID5-F0009/MID7
# 54        F0010/MID1-F0010/MID2
# 55        F0010/MID1-F0010/MID2
# 56        F0010/MID1-F0010/MID3
# 58        F0010/MID1-F0010/MID4
# 60        F0010/MID2-F0010/MID3
# 61        F0010/MID2-F0010/MID3
# 62        F0010/MID2-F0010/MID4
# ...                         ...
# 12070     F1000/MID1-F1000/MID7
# 12073     F1000/MID1-F1000/MID8
# 12074     F1000/MID1-F1000/MID9
# 12080     F1000/MID2-F1000/MID5
# 12081     F1000/MID2-F1000/MID5
# 12083     F1000/MID2-F1000/MID6
# 12085     F1000/MID2-F1000/MID7
# 12086     F1000/MID2-F1000/MID8
# 12088     F1000/MID2-F1000/MID9
# 12089     F1000/MID2-F1000/MID9
# 12090     F1000/MID3-F1000/MID4
# 12091     F1000/MID3-F1000/MID4
# 12092     F1000/MID3-F1000/MID5
# 12093     F1000/MID3-F1000/MID6
# 12094     F1000/MID3-F1000/MID7
# 12096     F1000/MID3-F1000/MID8
# 12097     F1000/MID3-F1000/MID9
# 12099     F1000/MID4-F1000/MID5
# 12100     F1000/MID4-F1000/MID6
# 12102     F1000/MID4-F1000/MID7
# 12109     F1000/MID5-F1000/MID7
# 12110     F1000/MID5-F1000/MID7
# 12112     F1000/MID5-F1000/MID9
# 12113     F1000/MID6-F1000/MID7
# 12115     F1000/MID6-F1000/MID8
# 12116     F1000/MID6-F1000/MID9
# 12118     F1000/MID7-F1000/MID8
# 12119     F1000/MID7-F1000/MID9
# 12120     F1000/MID7-F1000/MID9
# 12121     F1000/MID8-F1000/MID9
#
#                                          left_image_path  \
# 2      ../Data/recognizing-faces-in-the-wild/train/F0...
# 7      ../Data/recognizing-faces-in-the-wild/train/F0...
# 12     ../Data/recognizing-faces-in-the-wild/train/F0...
# 13     ../Data/recognizing-faces-in-the-wild/train/F0...
# 14     ../Data/recognizing-faces-in-the-wild/train/F0...
# 17     ../Data/recognizing-faces-in-the-wild/train/F0...
# 20     ../Data/recognizing-faces-in-the-wild/train/F0...
# 21     ../Data/recognizing-faces-in-the-wild/train/F0...
# 22     ../Data/recognizing-faces-in-the-wild/train/F0...
# 23     ../Data/recognizing-faces-in-the-wild/train/F0...
# 26     ../Data/recognizing-faces-in-the-wild/train/F0...
# 27     ../Data/recognizing-faces-in-the-wild/train/F0...
# 29     ../Data/recognizing-faces-in-the-wild/train/F0...
# 35     ../Data/recognizing-faces-in-the-wild/train/F0...
# 36     ../Data/recognizing-faces-in-the-wild/train/F0...
# 42     ../Data/recognizing-faces-in-the-wild/train/F0...
# 43     ../Data/recognizing-faces-in-the-wild/train/F0...
# 44     ../Data/recognizing-faces-in-the-wild/train/F0...
# 46     ../Data/recognizing-faces-in-the-wild/train/F0...
# 47     ../Data/recognizing-faces-in-the-wild/train/F0...
# 48     ../Data/recognizing-faces-in-the-wild/train/F0...
# 50     ../Data/recognizing-faces-in-the-wild/train/F0...
# 51     ../Data/recognizing-faces-in-the-wild/train/F0...
# 54     ../Data/recognizing-faces-in-the-wild/train/F0...
# 55     ../Data/recognizing-faces-in-the-wild/train/F0...
# 56     ../Data/recognizing-faces-in-the-wild/train/F0...
# 58     ../Data/recognizing-faces-in-the-wild/train/F0...
# 60     ../Data/recognizing-faces-in-the-wild/train/F0...
# 61     ../Data/recognizing-faces-in-the-wild/train/F0...
# 62     ../Data/recognizing-faces-in-the-wild/train/F0...
# ...                                                  ...
# 12070  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12073  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12074  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12080  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12081  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12083  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12085  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12086  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12088  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12089  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12090  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12091  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12092  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12093  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12094  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12096  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12097  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12099  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12100  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12102  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12109  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12110  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12112  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12113  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12115  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12116  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12118  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12119  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12120  ../Data/recognizing-faces-in-the-wild/train/F1...
# 12121  ../Data/recognizing-faces-in-the-wild/train/F1...
#
#                                         right_image_path  is_related
# 2      ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 7      ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 12     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 13     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 14     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 17     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 20     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 21     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 22     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 23     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 26     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 27     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 29     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 35     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 36     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 42     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 43     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 44     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 46     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 47     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 48     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 50     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 51     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 54     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 55     ../Data/recognizing-faces-in-the-wild/train/F0...           0
# 56     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 58     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 60     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 61     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# 62     ../Data/recognizing-faces-in-the-wild/train/F0...           1
# ...                                                  ...         ...
# 12070  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12073  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12074  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12080  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12081  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12083  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12085  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12086  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12088  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12089  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12090  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12091  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12092  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12093  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12094  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12096  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12097  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12099  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12100  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12102  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12109  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12110  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12112  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12113  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12115  ../Data/recognizing-faces-in-the-wild/train/F1...           0
# 12116  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12118  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12119  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12120  ../Data/recognizing-faces-in-the-wild/train/F1...           1
# 12121  ../Data/recognizing-faces-in-the-wild/train/F1...           0
#
# [6827 rows x 4 columns]

# %%
print(train_df.shape)
print(validation_df.shape)
print(test_df.shape)
# Out:
# (6827, 4)
# (1715, 4)
# (3580, 4)

# %%
train_df.shape[0]
# Out:
# 6827

# %%
train_df.shape[0]+validation_df.shape[0]+test_df.shape[0]
# Out:
# 12122

# %%
def batches_generator(batch_size, data_frame, shuffle=True):
    """Generates padded batches of tokens and tags."""
    
    n_samples = data_frame.shape[0]
    if shuffle:
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)

    n_batches = n_samples // batch_size
    
    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start
      
        pairs = [np.zeros((batch_size, 224, 224, 3)) for i in range(2)]
        targets = np.zeros((batch_size,))
        
        pair_index=0
        for idx in order[batch_start: batch_end]:
            left_image_array=np.asarray(Image.open(data_frame.iloc[idx]['left_image_path']))
            pairs[0][pair_index,:,:,:] = left_image_array
                        
            right_image_array=np.asarray(Image.open(data_frame.iloc[idx]['right_image_path']))
            pairs[1][pair_index,:,:,:] = right_image_array                        
            
            targets[pair_index] = data_frame.iloc[idx]['is_related']

            pair_index = pair_index+1
            
        yield pairs, targets

# %%
batch = batches_generator(10, train_df, shuffle=False)

# %%
next_item = next(batch)

# %%
len(next_item)
# Out:
# 2

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto', restore_best_weights=True)
checkpoint = ModelCheckpoint(filepath='model_{epoch:02d}_{val_loss:.2f}.hdf5')

# %%
history = model.fit_generator(
                    generator= batches_generator(10, train_df, shuffle=True), 
                    epochs=500,
                    steps_per_epoch = 1,
                    verbose=2, 
                    callbacks=[monitor], 
                    validation_data = batches_generator(10, validation_df, shuffle=True),
                    validation_steps = 1 )
# Out:
# WARNING:tensorflow:From C:\Users\srinivasan_b\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
#  - 103s - loss: 42.6974 - val_loss: 42.5106
# Epoch 2/500
#  - 8s - loss: 42.5325 - val_loss: 42.5572
# Epoch 3/500
#  - 8s - loss: 42.3016 - val_loss: 42.5063
# Epoch 4/500
#  - 8s - loss: 42.3357 - val_loss: 42.0096
# Epoch 5/500
#  - 8s - loss: 42.0963 - val_loss: 41.8677
# Epoch 6/500
#  - 8s - loss: 41.8450 - val_loss: 41.6794
# Epoch 7/500
#  - 9s - loss: 41.5733 - val_loss: 41.4380
# Epoch 8/500
#  - 8s - loss: 41.2914 - val_loss: 41.3642
# Epoch 9/500
#  - 8s - loss: 41.3633 - val_loss: 41.1498
# Epoch 10/500
#  - 8s - loss: 40.9520 - val_loss: 41.1835
# Epoch 11/500
#  - 8s - loss: 40.8372 - val_loss: 40.7689
# Epoch 12/500
#  - 8s - loss: 40.7782 - val_loss: 40.4494
# Epoch 13/500
#  - 8s - loss: 40.4247 - val_loss: 40.2070
# Epoch 14/500
#  - 8s - loss: 40.2785 - val_loss: 39.9963
# Epoch 15/500
#  - 8s - loss: 40.0536 - val_loss: 39.8253
# Epoch 16/500
#  - 8s - loss: 39.7700 - val_loss: 39.6110
# Epoch 17/500
#  - 8s - loss: 39.5843 - val_loss: 39.3864
# Epoch 18/500
#  - 8s - loss: 39.4771 - val_loss: 39.1918
# Epoch 19/500
#  - 8s - loss: 39.1326 - val_loss: 38.9649
# Epoch 20/500
#  - 8s - loss: 39.0017 - val_loss: 38.7719
# Epoch 21/500
#  - 8s - loss: 38.6983 - val_loss: 38.4608
# Epoch 22/500
#  - 8s - loss: 38.4423 - val_loss: 38.2914
# Epoch 23/500
#  - 8s - loss: 38.2637 - val_loss: 38.1730
# Epoch 24/500
#  - 8s - loss: 38.0056 - val_loss: 37.9543
# Epoch 25/500
#  - 8s - loss: 37.8585 - val_loss: 37.6210
# Epoch 26/500
#  - 9s - loss: 37.6183 - val_loss: 37.3890
# Epoch 27/500
#  - 8s - loss: 37.3666 - val_loss: 37.2670
# Epoch 28/500
#  - 8s - loss: 37.1821 - val_loss: 36.7909
# Epoch 29/500
#  - 8s - loss: 36.9415 - val_loss: 36.7851
# Epoch 30/500
#  - 8s - loss: 36.6436 - val_loss: 36.5347
# Epoch 31/500
#  - 8s - loss: 36.8168 - val_loss: 36.2841
# Epoch 32/500
#  - 8s - loss: 36.4524 - val_loss: 36.1709
# Epoch 33/500
#  - 8s - loss: 36.1692 - val_loss: 35.9615
# Epoch 34/500
#  - 8s - loss: 36.0670 - val_loss: 35.7925
# Epoch 35/500
#  - 8s - loss: 35.7378 - val_loss: 35.5346
# Epoch 36/500
#  - 8s - loss: 35.6061 - val_loss: 35.4000
# Epoch 37/500
#  - 8s - loss: 35.3897 - val_loss: 35.1321
# Epoch 38/500
#  - 8s - loss: 35.2331 - val_loss: 35.0299
# Epoch 39/500
#  - 8s - loss: 34.9406 - val_loss: 34.7524
# Epoch 40/500
#  - 8s - loss: 34.7959 - val_loss: 34.5689
# Epoch 41/500
#  - 8s - loss: 34.5970 - val_loss: 34.3475
# Epoch 42/500
#  - 8s - loss: 34.3396 - val_loss: 34.1643
# Epoch 43/500
#  - 8s - loss: 34.2783 - val_loss: 33.9820
# Epoch 44/500
#  - 8s - loss: 33.9423 - val_loss: 33.7055
# Epoch 45/500
#  - 8s - loss: 33.7390 - val_loss: 33.5653
# Epoch 46/500
#  - 8s - loss: 33.4534 - val_loss: 33.3657
# Epoch 47/500
#  - 8s - loss: 33.3942 - val_loss: 33.1224
# Epoch 48/500
#  - 8s - loss: 33.0902 - val_loss: 32.9137
# Epoch 49/500
#  - 8s - loss: 32.9734 - val_loss: 32.7244
# Epoch 50/500
#  - 8s - loss: 32.6706 - val_loss: 32.6124
# Epoch 51/500
#  - 8s - loss: 32.6262 - val_loss: 32.4301
# Epoch 52/500
#  - 8s - loss: 32.3586 - val_loss: 32.1199
# Epoch 53/500
#  - 8s - loss: 32.2677 - val_loss: 31.9715
# Epoch 54/500
#  - 8s - loss: 31.9566 - val_loss: 31.8947
# Epoch 55/500
#  - 8s - loss: 31.7802 - val_loss: 31.4869
# Epoch 56/500
#  - 8s - loss: 31.7019 - val_loss: 31.4137
# Epoch 57/500
#  - 8s - loss: 31.3301 - val_loss: 31.0905
# Epoch 58/500
#  - 8s - loss: 31.2062 - val_loss: 31.0794
# Epoch 59/500
#  - 8s - loss: 30.9897 - val_loss: 30.8380
# Epoch 60/500
#  - 8s - loss: 30.8698 - val_loss: 30.5334
# Epoch 61/500
#  - 8s - loss: 30.5924 - val_loss: 30.3287
# Epoch 62/500
#  - 8s - loss: 30.7054 - val_loss: 30.3623
# Epoch 63/500
#  - 8s - loss: 30.5230 - val_loss: 30.1948
# Epoch 64/500
#  - 8s - loss: 30.1520 - val_loss: 29.9673
# Epoch 65/500
#  - 8s - loss: 29.9352 - val_loss: 29.7766
# Epoch 66/500
#  - 8s - loss: 29.8394 - val_loss: 29.6199
# Epoch 67/500
#  - 8s - loss: 29.6789 - val_loss: 29.4247
# Epoch 68/500
#  - 8s - loss: 29.5206 - val_loss: 29.2153
# Epoch 69/500
#  - 8s - loss: 29.3643 - val_loss: 29.2304
# Epoch 70/500
#  - 8s - loss: 29.2232 - val_loss: 28.9611
# Epoch 71/500
#  - 8s - loss: 28.9708 - val_loss: 28.8538
# Epoch 72/500
#  - 8s - loss: 28.7236 - val_loss: 28.6087
# Epoch 73/500
#  - 8s - loss: 28.6008 - val_loss: 28.5204
# Epoch 74/500
#  - 8s - loss: 28.4409 - val_loss: 28.2568
# Epoch 75/500
#  - 8s - loss: 28.3105 - val_loss: 28.1869
# Epoch 76/500
#  - 8s - loss: 28.1765 - val_loss: 27.9518
# Epoch 77/500
#  - 8s - loss: 27.9390 - val_loss: 27.7753
# Epoch 78/500
#  - 8s - loss: 27.7849 - val_loss: 27.6515
# Epoch 79/500
#  - 8s - loss: 27.6695 - val_loss: 27.5141
# Epoch 80/500
#  - 8s - loss: 27.4612 - val_loss: 27.4014
# Epoch 81/500
#  - 8s - loss: 27.4384 - val_loss: 27.1788
# Epoch 82/500
#  - 8s - loss: 27.2571 - val_loss: 27.0213
# Epoch 83/500
#  - 8s - loss: 26.9786 - val_loss: 26.8964
# Epoch 84/500
#  - 8s - loss: 26.9311 - val_loss: 26.7131
# Epoch 85/500
#  - 8s - loss: 26.6720 - val_loss: 26.5611
# Epoch 86/500
#  - 8s - loss: 26.5779 - val_loss: 26.3727
# Epoch 87/500
#  - 8s - loss: 26.4329 - val_loss: 26.3259
# Epoch 88/500
#  - 8s - loss: 26.3081 - val_loss: 26.0269
# Epoch 89/500
#  - 8s - loss: 25.9821 - val_loss: 25.8553
# Epoch 90/500
#  - 8s - loss: 25.9341 - val_loss: 25.8821
# Epoch 91/500
#  - 8s - loss: 25.7833 - val_loss: 25.7378
# Epoch 92/500
#  - 8s - loss: 25.7585 - val_loss: 25.5398
# Epoch 93/500
#  - 8s - loss: 25.5140 - val_loss: 25.3635
# Epoch 94/500
#  - 8s - loss: 25.4552 - val_loss: 25.2866
# Epoch 95/500
#  - 8s - loss: 25.2913 - val_loss: 25.1484
# Epoch 96/500
#  - 8s - loss: 25.0901 - val_loss: 24.9192
# Epoch 97/500
#  - 8s - loss: 24.8465 - val_loss: 24.7749
# Epoch 98/500
#  - 8s - loss: 24.9108 - val_loss: 24.7261
# Epoch 99/500
#  - 8s - loss: 24.6731 - val_loss: 24.6175
# Epoch 100/500
#  - 8s - loss: 24.5100 - val_loss: 24.4049
# Epoch 101/500
#  - 8s - loss: 24.4119 - val_loss: 24.2661
# Epoch 102/500
#  - 8s - loss: 24.1849 - val_loss: 24.1118
# Epoch 103/500
#  - 8s - loss: 24.0540 - val_loss: 23.9901
# Epoch 104/500
#  - 8s - loss: 23.9056 - val_loss: 23.7862
# Epoch 105/500
#  - 8s - loss: 23.8028 - val_loss: 23.6157
# Epoch 106/500
#  - 8s - loss: 23.7027 - val_loss: 23.5337
# Epoch 107/500
#  - 8s - loss: 23.4441 - val_loss: 23.4611
# Epoch 108/500
#  - 8s - loss: 23.4287 - val_loss: 23.1075
# Epoch 109/500
#  - 8s - loss: 23.2010 - val_loss: 23.0013
# Epoch 110/500
#  - 8s - loss: 23.2676 - val_loss: 23.1041
# Epoch 111/500
#  - 8s - loss: 22.9149 - val_loss: 22.9557
# Epoch 112/500
#  - 8s - loss: 22.7284 - val_loss: 22.6979
# Epoch 113/500
#  - 8s - loss: 22.5904 - val_loss: 22.6872
# Epoch 114/500
#  - 8s - loss: 22.4445 - val_loss: 22.5408
# Epoch 115/500
#  - 8s - loss: 22.3075 - val_loss: 22.5506
# Epoch 116/500
#  - 8s - loss: 22.2879 - val_loss: 22.2281
# Epoch 117/500
#  - 8s - loss: 22.3210 - val_loss: 22.1255
# Epoch 118/500
#  - 8s - loss: 22.3217 - val_loss: 21.9303
# Epoch 119/500
#  - 8s - loss: 22.0016 - val_loss: 21.8763
# Epoch 120/500
#  - 8s - loss: 21.7959 - val_loss: 21.6923
# Epoch 121/500
#  - 8s - loss: 21.6575 - val_loss: 21.4972
# Epoch 122/500
#  - 8s - loss: 21.6241 - val_loss: 21.4520
# Epoch 123/500
#  - 8s - loss: 21.4901 - val_loss: 21.2749
# Epoch 124/500
#  - 8s - loss: 21.2648 - val_loss: 21.2433
# Epoch 125/500
#  - 8s - loss: 21.3106 - val_loss: 21.1931
# Epoch 126/500
#  - 8s - loss: 21.0890 - val_loss: 21.1800
# Epoch 127/500
#  - 8s - loss: 21.0423 - val_loss: 20.7954
# Epoch 128/500
#  - 8s - loss: 21.1986 - val_loss: 20.7335
# Epoch 129/500
#  - 8s - loss: 20.5957 - val_loss: 20.5839
# Epoch 130/500
#  - 8s - loss: 20.6409 - val_loss: 20.5220
# Epoch 131/500
#  - 8s - loss: 20.5779 - val_loss: 20.3360
# Epoch 132/500
#  - 8s - loss: 20.4805 - val_loss: 20.2545
# Epoch 133/500
#  - 8s - loss: 20.2780 - val_loss: 20.1877
# Epoch 134/500
#  - 8s - loss: 20.2045 - val_loss: 20.1435
# Epoch 135/500
#  - 8s - loss: 20.0616 - val_loss: 19.9638
# Epoch 136/500
#  - 8s - loss: 19.9989 - val_loss: 19.8788
# Epoch 137/500
#  - 8s - loss: 19.8860 - val_loss: 19.7528
# Epoch 138/500
#  - 8s - loss: 19.7694 - val_loss: 19.5784
# Epoch 139/500
#  - 8s - loss: 19.5626 - val_loss: 19.5608
# Epoch 140/500
#  - 8s - loss: 19.6278 - val_loss: 19.3932
# Epoch 141/500
#  - 8s - loss: 19.4374 - val_loss: 19.3618
# Epoch 142/500
#  - 8s - loss: 19.3641 - val_loss: 19.2369
# Epoch 143/500
#  - 8s - loss: 19.2703 - val_loss: 19.1491
# Epoch 144/500
#  - 8s - loss: 19.0842 - val_loss: 19.0583
# Epoch 145/500
#  - 8s - loss: 19.0482 - val_loss: 18.9684
# Epoch 146/500
#  - 8s - loss: 19.0563 - val_loss: 18.8684
# Epoch 147/500
#  - 8s - loss: 18.7847 - val_loss: 18.6045
# Epoch 148/500
#  - 8s - loss: 18.6672 - val_loss: 18.5332
# Epoch 149/500
#  - 8s - loss: 18.6945 - val_loss: 18.5635
# Epoch 150/500
#  - 8s - loss: 18.5287 - val_loss: 18.4419
# Epoch 151/500
#  - 8s - loss: 18.4719 - val_loss: 18.3884
# Epoch 152/500
#  - 8s - loss: 18.4404 - val_loss: 18.2508
# Epoch 153/500
#  - 8s - loss: 18.2060 - val_loss: 18.1895
# Epoch 154/500
#  - 8s - loss: 18.2725 - val_loss: 18.0021
# Epoch 155/500
#  - 8s - loss: 18.1052 - val_loss: 17.9049
# Epoch 156/500
#  - 8s - loss: 17.8307 - val_loss: 17.8128
# Epoch 157/500
#  - 8s - loss: 17.8264 - val_loss: 17.8276
# Epoch 158/500
#  - 8s - loss: 17.6949 - val_loss: 17.6636
# Epoch 159/500
#  - 8s - loss: 17.6621 - val_loss: 17.6029
# Epoch 160/500
#  - 8s - loss: 17.5567 - val_loss: 17.4277
# Epoch 161/500
#  - 8s - loss: 17.4810 - val_loss: 17.2112
# Epoch 162/500
#  - 8s - loss: 17.3456 - val_loss: 17.1775
# Epoch 163/500
#  - 8s - loss: 17.2069 - val_loss: 17.0973
# Epoch 164/500
#  - 8s - loss: 17.1959 - val_loss: 17.0776
# Epoch 165/500
#  - 8s - loss: 17.0043 - val_loss: 16.8908
# Epoch 166/500
#  - 8s - loss: 17.0495 - val_loss: 16.9012
# Epoch 167/500
#  - 8s - loss: 16.7442 - val_loss: 16.8396
# Epoch 168/500
#  - 8s - loss: 16.7556 - val_loss: 16.6602
# Epoch 169/500
#  - 8s - loss: 16.7408 - val_loss: 16.5588
# Epoch 170/500
#  - 8s - loss: 16.5589 - val_loss: 16.4766
# Epoch 171/500
#  - 8s - loss: 16.5622 - val_loss: 16.4233
# Epoch 172/500
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-22-c50fcb4817e5> in <module>
#       6                     callbacks=[monitor],
#       7                     validation_data = batches_generator(10, validation_df, shuffle=True),
# ----> 8                     validation_steps = 1 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     232                             val_enqueuer_gen,
#     233                             validation_steps,
# --> 234                             workers=0)
#     235                     else:
#     236                         # No need for try/except because
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1470             workers=workers,
#    1471             use_multiprocessing=use_multiprocessing,
# -> 1472             verbose=verbose)
#    1473
#    1474     @interfaces.legacy_generator_methods_support
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_generator.py in evaluate_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     328
#     329         while steps_done < steps:
# --> 330             generator_output = next(output_generator)
#     331             if not hasattr(generator_output, '__len__'):
#     332                 raise ValueError('Output of generator should be a tuple '
#
# StopIteration:

# %%
model.save_weights("finalmodels/final.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-fc524fa689e1> in <module>
# ----> 1 model.save_weights("finalmodels/final.h5")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\network.py in save_weights(self, filepath, overwrite)
#    1118             if not proceed:
#    1119                 return
# -> 1120         with h5py.File(filepath, 'w') as f:
#    1121             saving.save_weights_to_hdf5_group(f, self.layers)
#    1122             f.flush()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     174         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     175     elif mode == 'w':
# --> 176         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     177     elif mode == 'a':
#     178         # Open in append mode (read/write).
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = 'finalmodels/final.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302)
